# %%
from simjsr import convert

# %%
convert.from_chemkin("grimech3.0/chem.inp", thermo_file="grimech3.0/thermo.dat", out_file="test.yaml")
# Out:
# Wrote YAML mechanism file to 'test.yaml'.
# Mechanism contains 53 species and 325 reactions.
# 'test.yaml'
